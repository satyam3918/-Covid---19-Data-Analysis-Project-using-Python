# %% [markdown]
# # COVID DATA ANALYSIS PROJECT

# %%
import numpy as np
import pandas as pd

# %%
! pip install fsspec
# Out:
# ...
#      |████████████████████████████████| 92kB 4.2MB/s
# ...

# %%
url = 'https://raw.githubusercontent.com/SR1608/Datasets/main/covid-data.csv'

# %%
df = pd.read_csv(url , sep = ',')

# %%
df.head(5)
# Out:
#   iso_code continent  ... life_expectancy human_development_index
# 0      AFG      Asia  ...           64.83                   0.498
# 1      AFG      Asia  ...           64.83                   0.498
# 2      AFG      Asia  ...           64.83                   0.498
# 3      AFG      Asia  ...           64.83                   0.498
# 4      AFG      Asia  ...           64.83                   0.498
#
# [5 rows x 49 columns]

# %%
df.shape
# Out:
# (57394, 49)

# %%
df.dtypes
# Out:
# iso_code                               object
# continent                              object
# location                               object
# date                                   object
# total_cases                           float64
# new_cases                             float64
# new_cases_smoothed                    float64
# total_deaths                          float64
# new_deaths                            float64
# new_deaths_smoothed                   float64
# total_cases_per_million               float64
# new_cases_per_million                 float64
# new_cases_smoothed_per_million        float64
# total_deaths_per_million              float64
# new_deaths_per_million                float64
# new_deaths_smoothed_per_million       float64
# reproduction_rate                     float64
# icu_patients                          float64
# icu_patients_per_million              float64
# hosp_patients                         float64
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57394 entries, 0 to 57393
# Data columns (total 49 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   iso_code                            57071 non-null  object
#  1   continent                           56748 non-null  object
#  2   location                            57394 non-null  object
#  3   date                                57394 non-null  object
#  4   total_cases                         53758 non-null  float64
#  5   new_cases                           56465 non-null  float64
#  6   new_cases_smoothed                  55652 non-null  float64
#  7   total_deaths                        44368 non-null  float64
#  8   new_deaths                          56465 non-null  float64
#  9   new_deaths_smoothed                 55652 non-null  float64
#  10  total_cases_per_million             53471 non-null  float64
# ...

# %%
df.describe()
# Out:
#         total_cases      new_cases  ...  life_expectancy  human_development_index
# count  5.375800e+04   56465.000000  ...     56336.000000             49247.000000
# mean   1.677974e+05    1953.576941  ...        73.937780                 0.722223
# std    1.693038e+06   18269.650340  ...         7.397016                 0.153261
# min    1.000000e+00   -8261.000000  ...        53.280000                 0.354000
# 25%    1.800000e+02       0.000000  ...        69.870000                 0.601000
# 50%    2.070000e+03      14.000000  ...        75.345000                 0.752000
# 75%    2.235675e+04     235.000000  ...        79.380000                 0.847000
# max    5.515465e+07  646281.000000  ...        86.750000                 0.953000
#
# [8 rows x 45 columns]

# %%
df.nunique()
# Out:
# iso_code                                215
# continent                                 6
# location                                216
# date                                    323
# total_cases                           22672
# new_cases                              5432
# new_cases_smoothed                    11469
# total_deaths                           7704
# new_deaths                             1211
# new_deaths_smoothed                    2773
# total_cases_per_million               37531
# new_cases_per_million                 20662
# new_cases_smoothed_per_million        23781
# total_deaths_per_million              20046
# new_deaths_per_million                 3850
# new_deaths_smoothed_per_million        4588
# reproduction_rate                       361
# icu_patients                           1202
# icu_patients_per_million               2260
# hosp_patients                          2093
# hosp_patients_per_million              3477
# ...

# %%
df['location'].nunique()
# Out:
# 216

# %%
df['continent'].value_counts()
# Out:
# Europe           14828
# Africa           13637
# Asia             13528
# North America     9116
# South America     3404
# Oceania           2235
# Name: continent, dtype: int64

# %%
df['total_cases'].max()
# Out:
# 55154651.0

# %%
df['total_cases'].mean()
# Out:
# 167797.3688753302

# %%
df['total_deaths'].quantile(q=0.25)
# Out:
# 13.0

# %%
df['total_deaths'].quantile(q=0.5)
# Out:
# 84.0

# %%
df['total_deaths'].quantile(q=0.75)
# Out:
# 727.0

# %%
df.drop(['positive_rate'] ,axis = 1)
# Out:
#       iso_code continent  ... life_expectancy human_development_index
# 0          AFG      Asia  ...           64.83                   0.498
# 1          AFG      Asia  ...           64.83                   0.498
# 2          AFG      Asia  ...           64.83                   0.498
# 3          AFG      Asia  ...           64.83                   0.498
# 4          AFG      Asia  ...           64.83                   0.498
# ...        ...       ...  ...             ...                     ...
# 57389      NaN       NaN  ...             NaN                     NaN
# 57390      NaN       NaN  ...             NaN                     NaN
# 57391      NaN       NaN  ...             NaN                     NaN
# 57392      NaN       NaN  ...             NaN                     NaN
# 57393      NaN       NaN  ...             NaN                     NaN
#
# [57394 rows x 48 columns]

# %%
imp_col =    ['continent' , 'location' , 'date' , 'total_cases' , 'total_deaths' , 'gdp_per_capita' , 'human_development_index' ]

# %%
imp_column = df[['continent' , 'location' , 'date' , 'total_cases' , 'total_deaths' , 'gdp_per_capita' , 'human_development_index' ]]

# %%
imp_column
# Out:
#       continent       location  ... gdp_per_capita  human_development_index
# 0          Asia    Afghanistan  ...       1803.987                    0.498
# 1          Asia    Afghanistan  ...       1803.987                    0.498
# 2          Asia    Afghanistan  ...       1803.987                    0.498
# 3          Asia    Afghanistan  ...       1803.987                    0.498
# 4          Asia    Afghanistan  ...       1803.987                    0.498
# ...         ...            ...  ...            ...                      ...
# 57389       NaN  International  ...            NaN                      NaN
# 57390       NaN  International  ...            NaN                      NaN
# 57391       NaN  International  ...            NaN                      NaN
# 57392       NaN  International  ...            NaN                      NaN
# 57393       NaN  International  ...            NaN                      NaN
#
# [57394 rows x 7 columns]

# %%
pd.DataFrame.drop_duplicates(imp_column)
# Out:
#       continent       location  ... gdp_per_capita  human_development_index
# 0          Asia    Afghanistan  ...       1803.987                    0.498
# 1          Asia    Afghanistan  ...       1803.987                    0.498
# 2          Asia    Afghanistan  ...       1803.987                    0.498
# 3          Asia    Afghanistan  ...       1803.987                    0.498
# 4          Asia    Afghanistan  ...       1803.987                    0.498
# ...         ...            ...  ...            ...                      ...
# 57389       NaN  International  ...            NaN                      NaN
# 57390       NaN  International  ...            NaN                      NaN
# 57391       NaN  International  ...            NaN                      NaN
# 57392       NaN  International  ...            NaN                      NaN
# 57393       NaN  International  ...            NaN                      NaN
#
# [57394 rows x 7 columns]

# %%
imp_column.isnull()
# Out:
#        continent  location  ...  gdp_per_capita  human_development_index
# 0          False     False  ...           False                    False
# 1          False     False  ...           False                    False
# 2          False     False  ...           False                    False
# 3          False     False  ...           False                    False
# 4          False     False  ...           False                    False
# ...          ...       ...  ...             ...                      ...
# 57389       True     False  ...            True                     True
# 57390       True     False  ...            True                     True
# 57391       True     False  ...            True                     True
# 57392       True     False  ...            True                     True
# 57393       True     False  ...            True                     True
#
# [57394 rows x 7 columns]

# %%
imp_column.isnull().sum()
# Out:
# continent                    646
# location                       0
# date                           0
# total_cases                 3636
# total_deaths               13026
# gdp_per_capita              7027
# human_development_index     8147
# dtype: int64

# %%
imp_column.drop(imp_column[imp_column['continent'].isnull()==True].index, inplace = True)
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py:4174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
imp_column.shape
# Out:
# (56748, 7)

# %%
imp_column.head()
# Out:
#   continent     location  ... gdp_per_capita  human_development_index
# 0      Asia  Afghanistan  ...       1803.987                    0.498
# 1      Asia  Afghanistan  ...       1803.987                    0.498
# 2      Asia  Afghanistan  ...       1803.987                    0.498
# 3      Asia  Afghanistan  ...       1803.987                    0.498
# 4      Asia  Afghanistan  ...       1803.987                    0.498
#
# [5 rows x 7 columns]

# %%
imp_column['continent'].isnull().sum()
# Out:
# 0

# %%
imp_column.fillna(0)
# Out:
#       continent     location  ... gdp_per_capita  human_development_index
# 0          Asia  Afghanistan  ...       1803.987                    0.498
# 1          Asia  Afghanistan  ...       1803.987                    0.498
# 2          Asia  Afghanistan  ...       1803.987                    0.498
# 3          Asia  Afghanistan  ...       1803.987                    0.498
# 4          Asia  Afghanistan  ...       1803.987                    0.498
# ...         ...          ...  ...            ...                      ...
# 56743    Africa     Zimbabwe  ...       1899.775                    0.535
# 56744    Africa     Zimbabwe  ...       1899.775                    0.535
# 56745    Africa     Zimbabwe  ...       1899.775                    0.535
# 56746    Africa     Zimbabwe  ...       1899.775                    0.535
# 56747    Africa     Zimbabwe  ...       1899.775                    0.535
#
# [56748 rows x 7 columns]

# %%
imp_column.isnull().sum()
# Out:
# continent                      0
# location                       0
# date                           0
# total_cases                 3600
# total_deaths               12964
# gdp_per_capita              6704
# human_development_index     7501
# dtype: int64

# %%
imp_column['date']= pd.to_datetime(df['date'])
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
imp_column.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 56748 entries, 0 to 56747
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   continent                56748 non-null  object
#  1   location                 56748 non-null  object
#  2   date                     56748 non-null  datetime64[ns]
#  3   total_cases              53148 non-null  float64
#  4   total_deaths             43784 non-null  float64
#  5   gdp_per_capita           50044 non-null  float64
#  6   human_development_index  49247 non-null  float64
# dtypes: datetime64[ns](1), float64(4), object(2)
# memory usage: 3.5+ MB

# %%
import datetime

# %%
# imp_column['month'] = imp_column.DatetimeIndex(imp_column['date']).month

# %%
df.head()
# Out:
#   iso_code continent  ... life_expectancy human_development_index
# 0      AFG      Asia  ...           64.83                   0.498
# 1      AFG      Asia  ...           64.83                   0.498
# 2      AFG      Asia  ...           64.83                   0.498
# 3      AFG      Asia  ...           64.83                   0.498
# 4      AFG      Asia  ...           64.83                   0.498
#
# [5 rows x 49 columns]

# %%
df['td_to_tc'] = df['total_deaths']/df['total_cases']

# %%
df.head(10)
# Out:
#   iso_code continent  ... human_development_index td_to_tc
# 0      AFG      Asia  ...                   0.498      NaN
# 1      AFG      Asia  ...                   0.498      NaN
# 2      AFG      Asia  ...                   0.498      NaN
# 3      AFG      Asia  ...                   0.498      NaN
# 4      AFG      Asia  ...                   0.498      NaN
# 5      AFG      Asia  ...                   0.498      NaN
# 6      AFG      Asia  ...                   0.498      NaN
# 7      AFG      Asia  ...                   0.498      NaN
# 8      AFG      Asia  ...                   0.498      NaN
# 9      AFG      Asia  ...                   0.498      NaN
#
# [10 rows x 50 columns]

# %%
df.fillna(0)
# Out:
#       iso_code continent  ... human_development_index  td_to_tc
# 0          AFG      Asia  ...                   0.498  0.000000
# 1          AFG      Asia  ...                   0.498  0.000000
# 2          AFG      Asia  ...                   0.498  0.000000
# 3          AFG      Asia  ...                   0.498  0.000000
# 4          AFG      Asia  ...                   0.498  0.000000
# ...        ...       ...  ...                     ...       ...
# 57389        0         0  ...                   0.000  0.010057
# 57390        0         0  ...                   0.000  0.010057
# 57391        0         0  ...                   0.000  0.010057
# 57392        0         0  ...                   0.000  0.010057
# 57393        0         0  ...                   0.000  0.010057
#
# [57394 rows x 50 columns]

# %%
df.head()
# Out:
#   iso_code continent  ... human_development_index td_to_tc
# 0      AFG      Asia  ...                   0.498      NaN
# 1      AFG      Asia  ...                   0.498      NaN
# 2      AFG      Asia  ...                   0.498      NaN
# 3      AFG      Asia  ...                   0.498      NaN
# 4      AFG      Asia  ...                   0.498      NaN
#
# [5 rows x 50 columns]

# %%
df.tail()
# Out:
#       iso_code continent  ... human_development_index  td_to_tc
# 57389      NaN       NaN  ...                     NaN  0.010057
# 57390      NaN       NaN  ...                     NaN  0.010057
# 57391      NaN       NaN  ...                     NaN  0.010057
# 57392      NaN       NaN  ...                     NaN  0.010057
# 57393      NaN       NaN  ...                     NaN  0.010057
#
# [5 rows x 50 columns]

# %% [markdown]
# # DATA VISUALIZATION

# %%
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
plt.figure(figsize=(10,10))
sns.distplot(df['gdp_per_capita']);
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.scatter(x=df['total_cases'] , y = df['gdp_per_capita'])

# %%
sns.catplot(x="continent" , y="total_cases", kind="bar", data=df)
